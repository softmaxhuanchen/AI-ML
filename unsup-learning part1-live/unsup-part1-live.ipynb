# %% [markdown]
# ### intro
# 1. what is learning? the core idea:
#
# - obsersavtions compression -> model (much small) example: equations.
# - model -> predict the future.
# - predictive errors -> optimize the model (falsification)
#
# 2. what is machine learning? the core idea:
#
# - step1. obsersavtions (data) compression -> models with special architectures (much smaller otherwise overfit) .
# - step2. model -> predict unseen.
# - step3. predictive errors (ground truth) -> optimize the model in very small steps (training step2->step3->step2)
#
# - once we are happy with model, we can model to inference
#
# 3. the key to understanding ML, model is the same for people or for machine, only difference are the architectures.
#
# 4. 3 types AI/ML
#
# - unsup learning, unlabled data
# - supervised learning, labled data
# - RL reinforecement learning
#
#
# 5. New paradiam of software , github, hugging face
#
# 6. features/dimensions
#
# 7. training data
#
# 8. X (training data), and y(lable)
#
# 9. training vs inference
#
# 10. unsup learning, time-series, sup learning, NN, Algo trading, Robo advisors and LLM

# %% [markdown]
# ### unsup learning
# - What are clusters?

# %%
# Import the modules
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# Generate synthetic clusters
X, y = make_blobs(
    n_samples = 100,
    n_features = 2,
    centers=3, 
    random_state=3
)

y.shape
X.shape
# Out:
# (100, 2)

# %%
# Visualizing both classes
plt.scatter(X[:, 0], X[:, 1], c=y)

# %%
import pandas as pd
from pathlib import Path
import hvplot.pandas
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Read in the CSV file as a Pandas DataFrame
service_ratings_df = pd.read_csv(
    Path("Resources/service_ratings.csv")
)

# Review the DataFrame
service_ratings_df.head()
# Out:
#    mobile_app_rating  personal_banker_rating
# 0               3.50                    2.40
# 1               3.65                    3.14
# 2               2.90                    2.75
# 3               2.93                    3.36
# 4               2.89                    2.62

# %%
# Scatter plot of data

service_ratings_df.hvplot.scatter(
    x="mobile_app_rating", 
    y="personal_banker_rating"
)
# Out:
# :Scatter   [mobile_app_rating]   (personal_banker_rating)

# %% [markdown]
# Quesiton: how do the eyes dentify clusters?

# %% [markdown]
# ### K-means algorithm for clustering

# %%
from sklearn.cluster import KMeans
# Create and initialize the K-means model instance for 2 clusters
model = KMeans(n_clusters=2, random_state=1, n_init=100)

# Print the model
model
# Out:
# KMeans(n_clusters=2, n_init=100, random_state=1)

# %%
# Fit the data to the instance of the model
model.fit(service_ratings_df) # fit func to compress data into something can fit into the model
# Out:
# KMeans(n_clusters=2, n_init=100, random_state=1)

# %%
# Make predictions about the data clusters using the trained model

# Print the predictions

# %%
# Create a copy of the DataFrame


# Add a column to the DataFrame that contains the customer_ratings information


# Review the DataFrame

# %%
# Plot the datapoints based on the customer rating

# %% [markdown]
# ### How many centers should we assume? Elbow curve

# %%
import pandas as pd
from pathlib import Path
import hvplot.pandas
from sklearn.cluster import KMeans

# %%
service_ratings_df = pd.read_csv(
    Path("Resources/service_ratings.csv")
)

# Review the DataFrame
service_ratings_df.head()

# %%
# Define a DataFrame to hold the values for k and the corresponding inertia


# Review the DataFrame

# %%
# Plot the DataFrame

# %%
# Define the model with 4 clusters

# Fit the model

# Make predictions


# Add a class column with the labels

# %%
# Plot the clusters
